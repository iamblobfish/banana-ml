# %% [markdown]
# ### Denoising Autoencoders And Where To Find Them.
#
# Thanks to tha YSDA [course](https://github.com/yandexdataschool/Practical_DL) for this notebook.
#
#
# Today we're going to train deep autoencoders and deploy them to faces and search for similar images.
#
# Our new test subjects are human faces from the [lfw dataset](http://vis-www.cs.umass.edu/lfw/).

# %% [markdown]
# **Collab setting**

# %%
# if you're running in colab,
# 1. go to Runtime -> Change Runtimy Type -> GPU
# 2. uncomment this:
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/hw3_19/homework03/lfw_dataset.py -O lfw_dataset.py
# Out:
# --2019-11-07 14:24:27--  https://raw.githubusercontent.com/yandexdataschool/Practical_DL/hw3_19/homework03/lfw_dataset.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2734 (2.7K) [text/plain]
# Saving to: ‘lfw_dataset.py’
#
# lfw_dataset.py      100%[===================>]   2.67K  --.-KB/s    in 0s
#
# 2019-11-07 14:24:27 (29.8 MB/s) - ‘lfw_dataset.py’ saved [2734/2734]

# %%
import torch
import numpy as np

from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


EPOCHS = 100
BATCH_SIZE = 32
LEARNING_RATE = 1e-3

LATENT_DIMENSION = 4
BATCH_SIZE = 32

device = torch.device("cuda")

# %%
# !pip install scipy==1.1.0
# Out:
# Requirement already satisfied: scipy==1.1.0 in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1.0) (1.17.3)

# %%
import numpy as np
from lfw_dataset import fetch_lfw_dataset
from sklearn.model_selection import train_test_split
X, attr = fetch_lfw_dataset(use_raw=True,dimx=38,dimy=38)
X = X.transpose([0,3,1,2]).astype('float32') / 256.0

img_shape = X.shape[1:]

X_train, X_test = train_test_split(X, test_size=0.1,random_state=42)
# Out:
# images not found, donwloading...
# extracting...
# done
# attributes not found, downloading...
# done

# %%
X_train_tensor = torch.from_numpy(X_train).type(torch.DoubleTensor)
X_test_tensor = torch.Tensor(X_test).type(torch.DoubleTensor)

# %%
img_shape
# Out:
# (3, 38, 38)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.title('sample image')
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(X[i].transpose([1,2,0]))

print("X shape:",X.shape)
print("attr shape:",attr.shape)
# Out:
# X shape: (13143, 3, 38, 38)
# attr shape: (13143, 73)

# %% [markdown]
# ### Autoencoder architecture
#
# Let's design autoencoder as a single lasagne network, going from input image through bottleneck into the reconstructed image.
#
# <img src="http://nghiaho.com/wp-content/uploads/2012/12/autoencoder_network1.png" width=640px>

# %% [markdown]
# ## First step: PCA
#
# Principial Component Analysis is a popular dimensionality reduction method.
#
# Under the hood, PCA attempts to decompose object-feature matrix $X$ into two smaller matrices: $W$ and $\hat W$ minimizing _mean squared error_:
#
# $$\|(X W) \hat{W} - X\|^2_2 \to_{W, \hat{W}} \min$$
# - $X \in \mathbb{R}^{n \times m}$ - object matrix (**centered**);
# - $W \in \mathbb{R}^{m \times d}$ - matrix of direct transformation;
# - $\hat{W} \in \mathbb{R}^{d \times m}$ - matrix of reverse transformation;
# - $n$ samples, $m$ original dimensions and $d$ target dimensions;
#
# In geometric terms, we want to find d axes along which most of variance occurs. The "natural" axes, if you wish.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/9/90/PCA_fish.png/256px-PCA_fish.png)
#
#
# PCA can also be seen as a special case of an autoencoder.
#
# * __Encoder__: X -> Dense(d units) -> code
# * __Decoder__: code -> Dense(m units) -> X
#
# Where Dense is a fully-connected layer with linear activaton:   $f(X) = W \cdot X + \vec b $
#
#
# Note: the bias term in those layers is responsible for "centering" the matrix i.e. substracting mean.

# %%
# this class corresponds to view-function and may be used as a reshape layer 

class View(nn.Module):
    def __init__(self, *shape):
        super(View, self).__init__()
        self.shape = shape
    def forward(self, input):
        return input.view(*self.shape)

# %%
class pca_autoencoder(nn.Module):
    """
    Here we define a simple linear autoencoder as described above.
    We also flatten and un-flatten data to be compatible with image shapes
    """
    
    def __init__(self, code_size=32):
        super(pca_autoencoder, self).__init__()
        self.enc = nn.Sequential()
        self.enc.add_module('enc_view', View(-1, 3 * 38 * 38))
        self.enc.add_module('enc_linear',  nn.Linear(3 * 38 * 38, code_size))

        self.dec = nn.Sequential()
        self.dec.add_module('dec_view', nn.Linear(code_size, 3 * 38 * 38))
        self.dec.add_module('dec_linear',  View(-1, 3, 38, 38))

    def batch_loss(self, batch):
        reconstruction = self.dec(self.enc(batch))
        return torch.mean((batch - reconstruction)**2)

# %% [markdown]
# ### Train the model
#
# As usual, iterate minibatches of data and call train_step, then evaluate loss on validation data.
#
# __Note to py2 users:__ you can safely drop `flush=True` from any code below.

# %%
def train(model, dataset, num_epoch=32):
    model.double()
    model.to(device)
    gd = optim.Adam(model.parameters(), lr=0.01)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
    losses = []
    for epoch in range(num_epoch):
        for i, (batch) in enumerate(dataloader):
            gd.zero_grad()
            loss = model.batch_loss(batch.cuda())
            (loss).backward()
            losses.append(loss.detach().cpu().numpy())
            gd.step()
            gd.zero_grad()
        print("#%i, Train loss: %.7f"%(epoch+1,np.mean(losses)),flush=True)

# %%
def visualize(img, model):
    """Draws original, encoded and decoded images"""
    code = model.enc(img[None].cuda())
    reco = model.dec(code)

    plt.subplot(1,3,1)
    plt.title("Original")
    plt.imshow(img.cpu().numpy().transpose([1, 2, 0]).clip(0, 1))

    plt.subplot(1,3,2)
    plt.title("Code")
    plt.imshow(code.cpu().detach().numpy().reshape([code.shape[-1] // 2, -1]))

    plt.subplot(1,3,3)
    plt.title("Reconstructed")
    plt.imshow(reco[0].cpu().detach().numpy().transpose([1, 2, 0]).clip(0, 1))
    plt.show()

# %%
aenc = pca_autoencoder()
train(aenc, X_train_tensor, 40)
# Out:
# #1, Train loss: 1.2602599
# #2, Train loss: 0.6434928
# #3, Train loss: 0.4413538
# #4, Train loss: 0.3479976
# #5, Train loss: 0.2916746
# #6, Train loss: 0.2540051
# #7, Train loss: 0.2209445
# #8, Train loss: 0.1968099
# #9, Train loss: 0.1769649
# #10, Train loss: 0.1610376
# #11, Train loss: 0.1478344
# #12, Train loss: 0.1366353
# #13, Train loss: 0.1271191
# #14, Train loss: 0.1188719
# #15, Train loss: 0.1116205
# #16, Train loss: 0.1053635
# #17, Train loss: 0.0996947
# #18, Train loss: 0.0946332
# #19, Train loss: 0.0900802
# #20, Train loss: 2.3958023
# #21, Train loss: 2.2981858
# #22, Train loss: 2.2285346
# #23, Train loss: 2.1385585
# #24, Train loss: 2.0737858
# #25, Train loss: 1.9985476
# #26, Train loss: 1.9449425
# #27, Train loss: 1.8735009
# #28, Train loss: 1.8131522
# #29, Train loss: 1.7526001
# #30, Train loss: 1.6950023
# #31, Train loss: 1.6423355
# #32, Train loss: 1.5927718
# #33, Train loss: 1.5456462
# #34, Train loss: 1.5014326
# #35, Train loss: 1.4592552
# #36, Train loss: 1.4204646
# #37, Train loss: 1.3822778
# #38, Train loss: 1.3461997
# #39, Train loss: 1.3118805
# #40, Train loss: 1.2794115

# %%
dataloader_test = DataLoader(X_test_tensor, batch_size=BATCH_SIZE, shuffle=True)
scores = []
for i, (batch) in enumerate(dataloader_test):
    scores.append(aenc.batch_loss(batch.cuda()).data.cpu().numpy())
print (np.mean(scores))
# Out:
# 0.006804876900087729

# %%
for i in range(5):
    img = X_test_tensor[i]
    visualize(img,aenc)

# %% [markdown]
# ### Going deeper
#
# PCA is neat but surely we can do better. This time we want you to build a deep autoencoder by... stacking more layers.
#
# In particular, your encoder and decoder should be at least 3 layers deep each. You can use any nonlinearity you want and any number of hidden units in non-bottleneck layers provided you can actually afford training it.
#
# ![layers](https://pbs.twimg.com/media/CYggEo-VAAACg_n.png:small)
#
# A few sanity checks:
# * There shouldn't be any hidden layer smaller than bottleneck (encoder output).
# * Don't forget to insert nonlinearities between intermediate dense layers.
# * Convolutional layers are good idea. To undo convolution use L.Deconv2D, pooling - L.UpSampling2D.
# * Adding activation after bottleneck is allowed, but not strictly necessary.

# %%
class pca_autoencoder_deep(nn.Module):
    def __init__(self, code_size=32):
        super(pca_autoencoder_deep, self).__init__()
        self.enc = nn.Sequential()

        self.enc.add_module('conv2', nn.Conv2d(3, 20, kernel_size=3, padding=1, stride=2))
        self.enc.add_module('bn2', nn.BatchNorm2d(20))
        self.enc.add_module('ReLU2', nn.ReLU())
        
        self.enc.add_module('conv3', nn.Conv2d(20, 40, kernel_size=3, padding=1, stride=2))
        self.enc.add_module('bn3', nn.BatchNorm2d(40))
        self.enc.add_module('ReLU3', nn.ReLU())

        self.enc.add_module('view', View(-1, 4000))
        self.enc.add_module('lin0', nn.Linear(4000, code_size))
        self.enc.add_module('bn0', nn.BatchNorm1d(code_size))        
        

        self.dec = nn.Sequential()
        self.dec.add_module('lin', nn.Linear(code_size, 4000))
        self.dec.add_module('bn_lin1', nn.BatchNorm1d(4000))
        self.dec.add_module('ReLU_lin1', nn.ReLU())
      
        self.dec.add_module('view', View(-1, 40, 10, 10))

        self.dec.add_module('conv1', nn.ConvTranspose2d(40, 20, kernel_size=3, stride=2, padding=1))
        self.dec.add_module('bn1', nn.BatchNorm2d(20))
        self.dec.add_module('ReLU1', nn.ReLU())

        self.dec.add_module('conv2', nn.ConvTranspose2d(20, 3, kernel_size=2, stride=2))
        self.dec.add_module('bn2', nn.BatchNorm2d(3))


    def batch_loss(self, batch):
        reconstruction = self.enc(batch)
        reconstruction = self.dec(reconstruction)
        return torch.mean((batch - reconstruction)**2)

# %%
aenc_deep = pca_autoencoder_deep()

# %%
train(aenc_deep, X_train_tensor, 100)
# Out:
# #1, Train loss: 0.0954943
# #2, Train loss: 0.0515008
# #3, Train loss: 0.0365538
# #4, Train loss: 0.0290398
# #5, Train loss: 0.0245071
# #6, Train loss: 0.0214653
# #7, Train loss: 0.0192878
# #8, Train loss: 0.0176522
# #9, Train loss: 0.0163709
# #10, Train loss: 0.0153429
# #11, Train loss: 0.0145029
# #12, Train loss: 0.0137956
# #13, Train loss: 0.0131976
# #14, Train loss: 0.0126839
# #15, Train loss: 0.0122360
# #16, Train loss: 0.0118461
# #17, Train loss: 0.0114989
# #18, Train loss: 0.0111907
# #19, Train loss: 0.0109119
# #20, Train loss: 0.0106590
# #21, Train loss: 0.0104313
# #22, Train loss: 0.0102238
# #23, Train loss: 0.0100348
# #24, Train loss: 0.0098598
# #25, Train loss: 0.0096972
# #26, Train loss: 0.0095462
# #27, Train loss: 0.0094062
# #28, Train loss: 0.0092747
# #29, Train loss: 0.0091539
# #30, Train loss: 0.0090386
# #31, Train loss: 0.0089312
# #32, Train loss: 0.0088296
# #33, Train loss: 0.0087337
# #34, Train loss: 0.0086443
# #35, Train loss: 0.0085590
# #36, Train loss: 0.0084786
# #37, Train loss: 0.0084023
# #38, Train loss: 0.0083291
# #39, Train loss: 0.0082601
# #40, Train loss: 0.0081940
# #41, Train loss: 0.0081302
# #42, Train loss: 0.0080700
# #43, Train loss: 0.0080110
# #44, Train loss: 0.0079568
# #45, Train loss: 0.0079032
# #46, Train loss: 0.0078522
# #47, Train loss: 0.0078026
# #48, Train loss: 0.0077560
# #49, Train loss: 0.0077124
# #50, Train loss: 0.0076689
# #51, Train loss: 0.0076269
# #52, Train loss: 0.0075861
# #53, Train loss: 0.0075470
# #54, Train loss: 0.0075084
# #55, Train loss: 0.0074727
# #56, Train loss: 0.0074383
# #57, Train loss: 0.0074045
# #58, Train loss: 0.0073720
# #59, Train loss: 0.0073399
# #60, Train loss: 0.0073102
# #61, Train loss: 0.0072809
# #62, Train loss: 0.0072523
# #63, Train loss: 0.0072238
# #64, Train loss: 0.0071964
# #65, Train loss: 0.0071697
# #66, Train loss: 0.0071442
# #67, Train loss: 0.0071186
# #68, Train loss: 0.0070945
# #69, Train loss: 0.0070704
# #70, Train loss: 0.0070469
# #71, Train loss: 0.0070240
# #72, Train loss: 0.0070020
# #73, Train loss: 0.0069801
# #74, Train loss: 0.0069598
# #75, Train loss: 0.0069388
# #76, Train loss: 0.0069195
# #77, Train loss: 0.0069003
# #78, Train loss: 0.0068820
# #79, Train loss: 0.0068635
# #80, Train loss: 0.0068453
# #81, Train loss: 0.0068272
# #82, Train loss: 0.0068094
# #83, Train loss: 0.0067923
# #84, Train loss: 0.0067763
# #85, Train loss: 0.0067615
# #86, Train loss: 0.0067450
# #87, Train loss: 0.0067296
# #88, Train loss: 0.0067143
# #89, Train loss: 0.0066997
# #90, Train loss: 0.0066854
# #91, Train loss: 0.0066707
# #92, Train loss: 0.0066566
# #93, Train loss: 0.0066427
# #94, Train loss: 0.0066292
# #95, Train loss: 0.0066166
# #96, Train loss: 0.0066037
# #97, Train loss: 0.0065906
# #98, Train loss: 0.0065783
# #99, Train loss: 0.0065659
# #100, Train loss: 0.0065534

# %% [markdown]
# Training may take long, it's okay.

# %%
train(aenc_deep, X_train_tensor, 30)

# %% [markdown]
# **Check autoencoder shapes along different code_sizes. Check architecture of you encoder-decoder network is correct**

# %%
get_dim = lambda layer: np.prod(layer.output_shape[1:])
for code_size in [1,8,32,128,512,1024]:
    help_tensor = next(iter(DataLoader(X_train_tensor, batch_size=BATCH_SIZE)))
    model = pca_autoencoder_deep(code_size).to(device)
    encoder_out = model.enc(help_tensor.type('torch.FloatTensor').cuda())
    decoder_out = model.dec(encoder_out)
    print("Testing code size %i" % code_size)

    assert encoder_out.shape[1:]==torch.Size([code_size]),"encoder must output a code of required size"
    assert decoder_out.shape[1:]==img_shape,   "decoder must output an image of valid shape"

    assert (len(list(model.dec.children())) >= 6),  "decoder must contain at least 3 dense layers"

print("All tests passed!")
# Out:
# Testing code size 1
# Testing code size 8
# Testing code size 32
# Testing code size 128
# Testing code size 512
# Testing code size 1024
# All tests passed!

# %% [markdown]
# __Hint:__ if you're getting "Encoder layer is smaller than bottleneck" error, use code_size when defining intermediate layers.
#
# For example, such layer may have code_size*2 units.

# %% [markdown]
# ** Lets check you model's score. You should beat value of 0.005 **

# %%
import matplotlib.pyplot as plt

# %%
dataloader_test = DataLoader(X_test_tensor, batch_size=BATCH_SIZE, shuffle=True)
scores = []
for i, (batch) in enumerate(dataloader_test):
    aenc_deep.train(False)
    scores.append(aenc_deep.batch_loss(batch.cuda(device = device)).data.cpu().numpy())
    encoder_out = aenc_deep.enc(batch.cuda(device = device))
reconstruction_mse  = np.mean(scores)

assert reconstruction_mse <= 0.006, "Compression is too lossy. See tips below."
assert len(encoder_out.shape)==2 and encoder_out.shape[1]==32, "Make sure encoder has code_size units"
print("Final MSE:", reconstruction_mse)
for i in range(5):
    img = X_test_tensor[i]
    visualize(img,aenc_deep)
# Out:
# Final MSE: 0.0049607273179098415

# %% [markdown]
# __Tips:__ If you keep getting "Compression to lossy" error, there's a few things you might try:
#
# * Make sure it converged. Some architectures need way more than 32 epochs to converge. They may fluctuate a lot, but eventually they're going to get good enough to pass. You may train your network for as long as you want.
#
# * Complexity. If you already have, like, 152 layers and still not passing threshold, you may wish to start from something simpler instead and go in small incremental steps.
#
# * Architecture. You can use any combination of layers (including convolutions, normalization, etc) as long as __encoder output only stores 32 numbers per training object__.
#
# A cunning learner can circumvent this last limitation by using some manual encoding strategy, but he is strongly recommended to avoid that.

# %% [markdown]
# ## Denoising AutoEncoder
#
# Let's now make our model into a denoising autoencoder.
#
# We'll keep your model architecture, but change the way it trains. In particular, we'll corrupt it's input data randomly before each epoch.
#
# There are many strategies to apply noise. We'll implement two popular one: adding gaussian noise and using dropout.

# %%
def apply_gaussian_noise(X,sigma=0.1):
    """
    adds noise from normal distribution with standard deviation sigma
    :param X: image tensor of shape [batch,height,width,3]
    """
    norm_dist = torch.distributions.Normal(torch.tensor([0.0]), torch.tensor(sigma))
    noise = np.random.normal(loc=0.0, scale=sigma, size=X.shape).astype(np.float32)
    return X + noise

# %% [markdown]
# **noise tests**

# %%
apply_gaussian_noise(X[:1],sigma=0.01).dtype
# Out:
# dtype('float32')

# %%
theoretical_std = (X[:100].std()**2 + 0.5**2)**.5
our_std = apply_gaussian_noise(X[:100],sigma=0.5).std()
assert abs(theoretical_std - our_std) < 0.01, "Standard deviation does not match it's required value. Make sure you use sigma as std."
assert abs(apply_gaussian_noise(X[:100],sigma=0.5).mean() - X[:100].mean()) < 0.01, "Mean has changed. Please add zero-mean noise"

# %%
plt.subplot(1,4,1)
plt.imshow(X[0].transpose([1,2,0]))
plt.subplot(1,4,2)
plt.imshow(apply_gaussian_noise(X[:1],sigma=0.01)[0].transpose((1,2,0)).clip(0, 1))
plt.subplot(1,4,3)
plt.imshow(apply_gaussian_noise(X[:1],sigma=0.1)[0].transpose((1,2,0)).clip(0, 1))
plt.subplot(1,4,4)
plt.imshow(apply_gaussian_noise(X[:1],sigma=0.5)[0].transpose((1,2,0)).clip(0, 1))

# %%
#<Your code: define train function for denoising autoencoder as train function above>
def train_noise(model, dataset, num_epoch=50):
    model.double()
    model.to(device)
    gd = optim.Adam(model.parameters(), lr=0.001)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
    losses = []
    for epoch in range(num_epoch):
        for i, (batch) in enumerate(dataloader):
            gd.zero_grad()
            batch = batch.type(torch.DoubleTensor)
            noisy_batch = torch.from_numpy(apply_gaussian_noise(batch.numpy(), sigma=0.01)).type(torch.DoubleTensor)
            reconstruction = model.enc(noisy_batch.cuda())
            reconstruction = model.dec(reconstruction).type(torch.DoubleTensor).cuda()

            loss = torch.mean((batch.cuda() - reconstruction)**2)
            (loss).backward()
            losses.append(loss.detach().cpu().numpy())
            gd.step()
            gd.zero_grad()
        print("#%i, Train loss: %.7f"%(epoch+1,np.mean(losses)),flush=True)

# %%
X_train_noise = apply_gaussian_noise(X_train)
X_test_noise = apply_gaussian_noise(X_test)

# %%
X_train_tensor_n = torch.from_numpy(X_train_noise).type(torch.DoubleTensor)
X_test_tensor_n = torch.Tensor(X_test_noise).type(torch.DoubleTensor)

# %%
aenc = pca_autoencoder()
train_noise(aenc, X_train, 50)
# Out:
# #1, Train loss: 0.0689766
# #2, Train loss: 0.0448610
# #3, Train loss: 0.0362919
# #4, Train loss: 0.0313106
# #5, Train loss: 0.0280182
# #6, Train loss: 0.0255771
# #7, Train loss: 0.0236906
# #8, Train loss: 0.0221793
# #9, Train loss: 0.0208900
# #10, Train loss: 0.0198241
# #11, Train loss: 0.0188885
# #12, Train loss: 0.0180712
# #13, Train loss: 0.0173345
# #14, Train loss: 0.0166901
# #15, Train loss: 0.0161052
# #16, Train loss: 0.0155722
# #17, Train loss: 0.0150840
# #18, Train loss: 0.0146381
# #19, Train loss: 0.0142314
# #20, Train loss: 0.0138591
# #21, Train loss: 0.0135176
# #22, Train loss: 0.0131963
# #23, Train loss: 0.0128973
# #24, Train loss: 0.0126161
# #25, Train loss: 0.0123557
# #26, Train loss: 0.0121165
# #27, Train loss: 0.0118872
# #28, Train loss: 0.0116734
# #29, Train loss: 0.0114760
# #30, Train loss: 0.0112877
# #31, Train loss: 0.0111125
# #32, Train loss: 0.0109468
# #33, Train loss: 0.0107907
# #34, Train loss: 0.0106429
# #35, Train loss: 0.0105034
# #36, Train loss: 0.0103725
# #37, Train loss: 0.0102466
# #38, Train loss: 0.0101286
# #39, Train loss: 0.0100170
# #40, Train loss: 0.0099089
# #41, Train loss: 0.0098092
# #42, Train loss: 0.0097100
# #43, Train loss: 0.0096168
# #44, Train loss: 0.0095274
# #45, Train loss: 0.0094430
# #46, Train loss: 0.0093608
# #47, Train loss: 0.0092828
# #48, Train loss: 0.0092074
# #49, Train loss: 0.0091360
# #50, Train loss: 0.0090659

# %% [markdown]
# __Note:__ if it hasn't yet converged, increase the number of iterations.
#
# __Bonus:__ replace gaussian noise with masking random rectangles on image.

# %% [markdown]
# ** Let's evaluate!!! **

# %%
dataloader_test = DataLoader(X_test_tensor_n, batch_size=BATCH_SIZE, shuffle=True)
scores = []
for i, (batch) in enumerate(dataloader_test):
    scores.append(aenc.batch_loss(batch.cuda(device = device)).data.cpu().numpy())
    encoder_out = aenc.enc(batch.cuda(device = device))
reconstruction_mse  = np.mean(scores)

print("Final MSE:", reconstruction_mse)
for i in range(5):
    img = X_test_tensor_n[i]
    visualize(img,aenc)
# Out:
# Final MSE: 0.015684222367961055

# %% [markdown]
# ### Image retrieval with autoencoders
#
# So we've just trained a network that converts image into itself imperfectly. This task is not that useful in and of itself, but it has a number of awesome side-effects. Let's see it in action.
#
# First thing we can do is image retrieval aka image search. We we give it an image and find similar images in latent space.
#
# To speed up retrieval process, we shall use Locality-Sensitive Hashing on top of encoded vectors. We'll use scikit-learn's implementation for simplicity. In practical scenario, you may want to use [specialized libraries](https://erikbern.com/2015/07/04/benchmark-of-approximate-nearest-neighbor-libraries.html) for better performance and customization.

# %%
#encodes batch of images into a codes
codes = []

dataloader = DataLoader(X_train_tensor, batch_size=BATCH_SIZE, shuffle=False)
for i, (batch) in enumerate(dataloader):
    codes.append(aenc_deep.enc(batch.double().cuda()).data.cpu().numpy())
#     print(codes[-1].shape)

# %%
batch.shape
# Out:
# torch.Size([20, 3, 38, 38])

# %%
codes = np.concatenate(codes, axis=0)

# %%
np.linalg.norm(codes[0])
# Out:
# 40.523864152511884

# %%
# codes = codes / np.expand_dims(np.linalg.norm(codes, axis=1), 1)

# %%
assert codes.shape[0] == X_train_tensor.shape[0]

# %%
from sklearn.neighbors import LSHForest
lshf = LSHForest(n_estimators=50).fit(codes)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/neighbors/approximate.py:258: DeprecationWarning: LSHForest has poor performance and has been deprecated in 0.19. It will be removed in version 0.21.
#   DeprecationWarning)

# %%
images = torch.from_numpy(X_train).type(torch.DoubleTensor)

# %%
images.shape
# Out:
# torch.Size([11828, 3, 38, 38])

# %%
def get_similar(image, n_neighbors=5):
    assert len(image.shape)==3,"image must be [batch,height,width,3]"
    image = image.view((1, *image.shape))
    print('image shape ', image.shape)

    code = aenc_deep.enc(image.cuda()).detach().cpu().numpy()
    
    (distances,),(idx,) = lshf.kneighbors(code, n_neighbors=11)
    #<Your code: using lshf.kneighbors find nearest neighbors>
    
    return distances,images[idx]

# %%
def show_similar(image):
#     image = np.transpose(image)

    print('in show silm', image.shape)
#     image = np.expand_dims(image, axis=0)
#     print('in show silm', image.shape)
    distances,neighbors = get_similar(image,n_neighbors=11)
    
    plt.figure(figsize=[8,6])
    plt.subplot(3,4,1)
    plt.imshow(image.cpu().numpy().transpose([1,2,0]))
    plt.title("Original image")
    
    for i in range(11):
        plt.subplot(3,4,i+2)
        plt.imshow(neighbors[i].cpu().numpy().transpose([1,2,0]))
        plt.title("Dist=%.3f"%distances[i])
    plt.show()

# %%
X_test_tensor[2].shape
# Out:
# torch.Size([3, 38, 38])

# %%
(X_test_tensor).shape
# Out:
# torch.Size([1315, 3, 38, 38])

# %%
#smiles
show_similar(X_test_tensor[2])
# Out:
# in show silm torch.Size([3, 38, 38])
# image shape  torch.Size([1, 3, 38, 38])

# %%
#ethnicity
show_similar(X_test_tensor[500])
# Out:
# in show silm torch.Size([3, 38, 38])
# image shape  torch.Size([1, 3, 38, 38])

# %%
#glasses
show_similar(X_test_tensor[7])
# Out:
# in show silm torch.Size([3, 38, 38])
# image shape  torch.Size([1, 3, 38, 38])

# %% [markdown]
# ## Cheap image morphing

# %% [markdown]
# Here you should take two full-sized objects, code it and obtain intermediate object by decoding an intermixture code.
#
# $Code_{mixt} = a1\cdot code1 + a2\cdot code2$

# %%
for _ in range(5):
    image1,image2 = np.random.randint(0, X_train_tensor.shape[0], size=2)
    image1 = X_train_tensor[image1]
    image2 = X_train_tensor[image2]

    image1 = image1.view((1, *image1.shape))
    image2 = image2.view((1, *image2.shape))
    
    code1 = aenc_deep.enc(image1.cuda())
    code2 = aenc_deep.enc(image2.cuda())


    plt.figure(figsize=[10,4])
    for i,a in enumerate(np.linspace(0,1,num=7)):

        output_code = a * code1 + (1 - a) * code2
        output_image = aenc_deep.dec(output_code)[0]
        plt.subplot(1,7,i+1)
        plt.imshow(output_image.cpu().detach().numpy().transpose([1,2,0]))
        plt.title("a=%.2f"%a)

    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Of course there's a lot more you can do with autoencoders.
#
# If you want to generate images from scratch, however, we recommend you our honor track seminar about generative adversarial networks.
